# %%
for e in range(0,81):  #Recorre 80 números

    temp = e-30  #Poner temperatura a -30

    if temp < 0:  #Mensaje según distintos casos
        print(str(temp) + " muy frio")
    if -1 < temp  < 25:
            print(str(temp) + " templado")
    if 24 < temp:
            print(str(temp) + " caluroso")
# Out:
# -30 muy frio
# -29 muy frio
# -28 muy frio
# -27 muy frio
# -26 muy frio
# -25 muy frio
# -24 muy frio
# -23 muy frio
# -22 muy frio
# -21 muy frio
# -20 muy frio
# -19 muy frio
# -18 muy frio
# -17 muy frio
# -16 muy frio
# -15 muy frio
# -14 muy frio
# -13 muy frio
# -12 muy frio
# -11 muy frio
# -10 muy frio
# -9 muy frio
# -8 muy frio
# -7 muy frio
# -6 muy frio
# -5 muy frio
# -4 muy frio
# -3 muy frio
# -2 muy frio
# -1 muy frio
# 0 templado
# 1 templado
# 2 templado
# 3 templado
# 4 templado
# 5 templado
# 6 templado
# 7 templado
# 8 templado
# 9 templado
# 10 templado
# 11 templado
# 12 templado
# 13 templado
# 14 templado
# 15 templado
# 16 templado
# 17 templado
# 18 templado
# 19 templado
# 20 templado
# 21 templado
# 22 templado
# 23 templado
# 24 templado
# 25 caluroso
# 26 caluroso
# 27 caluroso
# 28 caluroso
# 29 caluroso
# 30 caluroso
# 31 caluroso
# 32 caluroso
# 33 caluroso
# 34 caluroso
# 35 caluroso
# 36 caluroso
# 37 caluroso
# 38 caluroso
# 39 caluroso
# ...

# %%
for e in range(5,101):  #Este es el ciclo que recorre los números del uno al 100
    if e%5 == e%10 == 0:  #Check que es múltiplo de 10
        print(str(e) + " bip bip")
    elif e%5 == 0: #check que es múltiplo de 5
        print(str(e) + " bip")
# Out:
# 5 bip
# 10 bip bip
# 15 bip
# 20 bip bip
# 25 bip
# 30 bip bip
# 35 bip
# 40 bip bip
# 45 bip
# 50 bip bip
# 55 bip
# 60 bip bip
# 65 bip
# 70 bip bip
# 75 bip
# 80 bip bip
# 85 bip
# 90 bip bip
# 95 bip
# 100 bip bip

# %%
a = int(input("ingrese el primer numero ") )  #Recibe primer número
b = int(input("ingrese el segundo numero "))  #Recibe segundo número
num = a + b  #Suma los números
#Arroja mensaje dependiendo el resultado
if num < 50:
    print("Nivel Principiante")
if 49 < num < 80:
    print("Nivel intermedio")
if 79 < num:
    print("Nivel pro")
# Out:
# ingrese el primer numero 27
# ingrese el segundo numero 18
# Nivel Principiante

# %%
edad = int(input("Coloque su edad: "))  #Recibe edad
GustaMusica = input("Le gusta la musica? responda si o no: ") #Pregunta si le gusta la música
GustaBailar = input("Le gusta bailar? responda si o no: ") #Pregunta si le gusta bailar
#Da resultado según parametros recibidos
if 18 <= edad and GustaBailar == "si" and GustaMusica == "si":
    print("Eres una estrella de la fiesta")
elif GustaMusica == "si" and GustaBailar == "no":
    print("Te gusta la música, pero no tanto bailar")
else:
    print("Tienes tu propio estilo")
# Out:
# Coloque su edad: 20
# Le gusta la musica? responda si o no: si
# Le gusta bailar? responda si o no: si
# Eres una estrella de la fiesta
